# %% [markdown]
# # Library

# %%
import pandas as pd
# MAPS
import folium
from streamlit_folium import folium_static

    ## Gráficos
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Loading dataset

# %%
df = pd.read_csv('zomato.csv')

# %% [markdown]
# # Funções

# %% [markdown]
# ## Limpeza do dataset

# %%
def clean_data(df):
#Correção do espaço
    lista_cols = list(df.head(0)) 
    for cols in lista_cols:
        # Verificar
        if  type(df.loc[0 , cols]) == str:
            # Cocertar o espaço 'texto ' p/ 'texto'
            df.loc[:, cols] = df.loc[:, cols].str.strip() 
            print('Funcionou str')
            # Remover o 'NaN'
            df = df.loc[(df[cols] != 'NaN') |(df[cols] != 'nan'), :]
        else: 
            print('Funcionou float or int')
            # Armazenar o tipo 
            classe = type(df.loc[0,cols])
            # Mudo o tipo para str
            df[cols]= df[cols].astype(str)
            # Concertar os espaços
            df.loc[:, cols] = df.loc[:, cols].str.strip()
            # Remover o 'NaN'
            df = df.loc[(df[cols] != 'NaN') |(df[cols] != 'nan'), :]
            # Converto para tipo anterior
            df[cols]= df[cols].astype(classe)
    
    return(df)

# Chamando a função de limpeza clean_data
df =clean_data(df)
# Out:
# Funcionou float or int
# Funcionou float or int
# Funcionou str
# Funcionou float or int
# Funcionou str
# Funcionou str
# Funcionou str
# Funcionou str
# Funcionou float or int
# Funcionou float or int
# Funcionou str
# Funcionou float or int
# Funcionou str
# Funcionou float or int
# Funcionou float or int
# Funcionou float or int
# Funcionou float or int
# Funcionou float or int
# Funcionou float or int
# Funcionou str
# Funcionou str
# Funcionou float or int
# Funcionou str
# Funcionou str
# Funcionou str

# %% [markdown]
# #### Automátiza o processo

# %% [markdown]
# Tem ver quais os prantos que mais saem e tem maior nota, estes são os pratos principais.
# E tenho que ver qual restaurante eles veem! É claro os melhores

# %% [markdown]
# Quais são os 5 principais tipos culinário ?

# %%
# Quais os 5 principais tipos culinários ?
                #Quais os pratos que mais saem? 
df2 = df.loc[:, ['Cuisines',  'Restaurant Name', 'Country_id','City', 'Average Cost for two', 'Aggregate rating', 'Votes']]
        # Bem para resolver o problema de várias culinárias em uma linha, vamos pegas nomes e coloca []
df2['Cuisines'] = df2['Cuisines'].str.split(', ')
        # Dar uma linha para cada elemento
df_exploded = df2.explode('Cuisines')
        # Agrupando
top=df_exploded.loc[:,['Cuisines',  'Restaurant Name']].groupby(['Cuisines'] ).count().reset_index().sort_values(['Restaurant Name'], ascending= False)
        # Resetando o index
top_cuisines = top.loc[:5,:].reset_index()
        # Deletando a coluna 'index'
top_cuisines.drop("index" ,axis='columns', inplace=True)
        # Selecionando somente os cincos primeiros
top_cuisines = top_cuisines.iloc[0:5,:]
top_cuisines
# Out:
#        Cuisines  Restaurant Name
# 0  North Indian             1694
# 1       Chinese             1304
# 2     Fast Food             1100
# 3       Italian             1002
# 4      American              765

# %%
# Armazento top_cuisines em dicionário
# top_cuisines=[]

# %%
top_5_list = list(top_cuisines['Cuisines'])

# %%
Valor1 = 'Name'
# Out:
# ['North Indian', 'Chinese', 'Fast Food', 'Italian', 'American']

# %%
top_library = [
        {'Cuisines': 'Tipo de comida', 'Restaurant Name': 'Name', 'Country_id': 'Name', 'City': 'Name0', 'Average Cost for two': 0, 'Aggregate rating': 5, 'Votes': 10,},
        {'Cuisines': 'Tipo de comida', 'Restaurant Name': 'Name', 'Country_id': 'Name', 'City': 'Name1', 'Average Cost for two': 1, 'Aggregate rating': 6, 'Votes': 11,},
        {'Cuisines': 'Tipo de comida', 'Restaurant Name': 'Name', 'Country_id': 'Name', 'City': 'Name2', 'Average Cost for two': 2, 'Aggregate rating': 7, 'Votes': 12,},
        {'Cuisines': 'Tipo de comida', 'Restaurant Name': 'Name', 'Country_id': 'Name', 'City': 'Name3', 'Average Cost for two': 3, 'Aggregate rating': 8, 'Votes': 13,},
        {'Cuisines': 'Tipo de comida', 'Restaurant Name': 'Name', 'Country_id': 'Name', 'City': 'Name4', 'Average Cost for two': 4, 'Aggregate rating': 9, 'Votes': 14,},
         
         
         ]

# %%
dados[1]['Votes'] = 18
dados[1]['Votes']
# Out:
# 18

# %%
index = 1
top_cuisines.loc[index, 'Cuisines']
# Out:
# 'Chinese'

# %%
df_exploded.loc[0,:]
# Out:
# Cuisines                                   Italian
# Restaurant Name         Mama Lou's Italian Kitchen
# Country_id                             Philippines
# City                                Las Piñas City
# Average Cost for two                          1100
# Aggregate rating                               4.6
# Votes                                          619
# Name: 0, dtype: object

# %%
#Selecionando os melhores restaurantes pela maior nota e quantidade de votos
lista = list(range(len(top_cuisines['Cuisines'])))

top_cuisines.loc[index, 'Cuisines']

for index in lista:
    filtro = df_exploded['Cuisines'].str.contains(top_cuisines.loc[index, 'Cuisines'])
    df_sel=df_exploded.loc[filtro != False,:].sort_values(['Aggregate rating','Votes'], ascending= False)
    df_sel = df_sel.reset_index()
    df_sel.drop("index", axis = 'columns', inplace=True)
    df_sel = df_sel.iloc[0:2,: ]
# Alterando o top_library
    top_library[index]['Cuisines']              = df_sel.loc[0, 'Cuisines']
    top_library[index]['Restaurant Name']       = df_sel.loc[0, 'Restaurant Name'] 
    top_library[index]['Country_id']            = df_sel.loc[0, 'Country_id']
    top_library[index]['City']                  = df_sel.loc[0, 'City']   
    top_library[index]['Average Cost for two']  = df_sel.loc[0, 'Average Cost for two']
    top_library[index]['Aggregate rating']      = df_sel.loc[0, 'Aggregate rating']   
    top_library[index]['Votes']                 = df_sel.loc[0, 'Votes']

# %%
top_library
# Out:
# [{'Cuisines': 'North Indian',
#   'Restaurant Name': 'Byg Brewski Brewing Company',
#   'Country_id': 'India',
#   'City': 'Bangalore',
#   'Average Cost for two': 1600,
#   'Aggregate rating': 4.9,
#   'Votes': 17394},
#  {'Cuisines': 'Chinese',
#   'Restaurant Name': 'Barbeque Nation',
#   'Country_id': 'India',
#   'City': 'Kolkata',
#   'Average Cost for two': 1800,
#   'Aggregate rating': 4.9,
#   'Votes': 8271},
#  {'Cuisines': 'Fast Food',
#   'Restaurant Name': 'Hitchki',
#   'Country_id': 'India',
#   'City': 'Mumbai',
#   'Average Cost for two': 1200,
#   'Aggregate rating': 4.9,
#   'Votes': 3524},
#  {'Cuisines': 'Italian',
#   'Restaurant Name': 'Byg Brewski Brewing Company',
#   'Country_id': 'India',
#   'City': 'Bangalore',
#   'Average Cost for two': 1600,
#   'Aggregate rating': 4.9,
#   'Votes': 17394},
#  {'Cuisines': 'American',
#   'Restaurant Name': 'Hitchki',
#   'Country_id': 'India',
#   'City': 'Mumbai',
#   'Average Cost for two': 1200,
# ...

# %%
#tp = pd.DataFrame(top_library)
# Out:
#        Cuisines              Restaurant Name Country_id       City  \
# 0  North Indian  Byg Brewski Brewing Company      India  Bangalore
# 1       Chinese              Barbeque Nation      India    Kolkata
# 2     Fast Food                      Hitchki      India     Mumbai
# 3       Italian  Byg Brewski Brewing Company      India  Bangalore
# 4      American                      Hitchki      India     Mumbai
#
#    Average Cost for two  Aggregate rating  Votes
# 0                  1600               4.9  17394
# 1                  1800               4.9   8271
# 2                  1200               4.9   3524
# 3                  1600               4.9  17394
# 4                  1200               4.9   3524

# %%
df2 = df.loc[:, ['Cuisines', 'Aggregate rating', 'Restaurant Name']]
        # Bem para resolver o problema de várias culinárias em uma linha, vamos pegas nomes e coloca []
df2['Cuisines'] = df2['Cuisines'].str.split(', ')
        # Dar uma linha para cada elemento
df_exploded = df2.explode('Cuisines')
filtro = df_exploded['Restaurant Name'].str.contains('Sushi Samba')
condicao = df_exploded.loc[filtro != False,['Cuisines', 'Aggregate rating', 'Restaurant Name']].groupby(['Cuisines', 'Restaurant Name']).mean().reset_index().sort_values('Aggregate rating', ascending= False)

condicao
#if 'Darshan' in boca.values:
 #   print('Tem')
# Out:
#     Cuisines Restaurant Name  Aggregate rating
# 0  Brazilian     Sushi Samba               4.9
# 1   Japanese     Sushi Samba               4.9
# 2   Peruvian     Sushi Samba               4.9
# 3      Sushi     Sushi Samba               4.9

# %% [markdown]
# ## Preenchimento do nome dos países

# %%
df.head(1)
# Out:
#    Restaurant ID             Restaurant Name  Country Code            City  \
# 0        6310675  Mama Lou's Italian Kitchen           162  Las Piñas City
#
#                                              Address          Locality  \
# 0  Block 1, Lot 36, Tropical Avenue Corner Tropic...  BF International
#
#                    Locality Verbose   Longitude   Latitude Cuisines  ...  \
# 0  BF International, Las Piñas City  121.009787  14.447615  Italian  ...
#
#            Currency Has Table booking  Has Online delivery  Is delivering now  \
# 0  Botswana Pula(P)                 1                    0                  0
#
#    Switch to order menu  Price range  Aggregate rating  Rating color  \
# 0                     0            3               4.6        3F7E00
#
#   Rating text Votes
# 0   Excellent   619
#
# [1 rows x 21 columns]

# %%
COUNTRIES = {
1: "India",
14: "Australia",
30: "Brazil",
37: "Canada",
94: "Indonesia",
148: "New Zeland",
162: "Philippines",
166: "Qatar",
184: "Singapure",
189: "South Africa",
191: "Sri Lanka",
208: "Turkey",
214: "United Arab Emirates",
215: "England",
216: "United States of America",
}
def country_name(country_id):
    return COUNTRIES[country_id]

# %%
df['Country_id'] = df['Country Code'].apply(country_name)

# %% [markdown]
# ## Criação do Tipo de Categoria de Comida

# %%
def create_price_tye(price_range):
    if price_range == 1:
        return "cheap"
    elif price_range == 2:
        return "normal"
    elif price_range == 3:
        return "expensive"
    else:
        return "gourmet"

# %%
df['Price_range']= df['Price range'].apply(create_price_tye)

# %% [markdown]
# ## Criação do nome das cores

# %%
COLORS = {
"3F7E00": "darkgreen",
"5BA829": "green",
"9ACD32": "lightgreen",
"CDD614": "orange",
"FFBA00": "red",
"CBCBC8": "darkred",
"FF7800": "darkred",
}
def color_name(color_code):
    return COLORS[color_code]

# %%
# Usando a função apply para aplicar no dataset
df['color_name']=df['Rating color'].apply(color_name)

# %% [markdown]
# ## Renomear as colunas do DataFrame

# %%
def rename_columns(dataframe):
    df = dataframe.copy()
    title = lambda x: inflection.titleize(x)
    snakecase = lambda x: inflection.underscore(x)
    spaces = lambda x: x.replace(" ", "")
    cols_old = list(df.columns)
    cols_old = list(map(title, cols_old))
    cols_old = list(map(spaces, cols_old))
    cols_new = list(map(snakecase, cols_old))
    df.columns = cols_new
    return df
#rename_columns(df)

# %%
#df["cuisines"] = df.loc[:, "Cuisines"].apply(lambda x: x.split(",")[0])

# %%
df['Cuisines'].unique()
# Out:
# array(['Italian', 'European, Asian',
#        'Filipino, American, Italian, Bakery', ...,
#        'Fast Food, Izgara, Seafood, Tea, Coffee', 'Home-made, Izgara',
#        'Restaurant Cafe, Kebab, Turkish Pizza'], dtype=object)

# %%
len(dff)
# Out:
# 7527

# %%
dff = df.loc[:, ['Cuisines', 'Aggregate rating']]
contador = 0
while contador <7527 :
    dff.loc[contador, 'Cuisines'] = [dff.loc[contador, 'Cuisines']]

#df_exploded = dff.explode('Cuisines')
#df_exploded
#df_aux = df_exploded.loc[:, ['Cuisines', 'Aggregate rating']].groupby('Cuisines').mean().sort_values('Aggregate rating', ascending = False)
#df_aux
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 4
#       2 contador = 0
#       3 while contador <7527 :
# ----> 4     dff.loc[contador, 'Cuisines'] = [dff.loc[contador, 'Cuisines']]
#       6 #df_exploded = dff.explode('Cuisines')
#       7 #df_exploded
#       8 #df_aux = df_exploded.loc[:, ['Cuisines', 'Aggregate rating']].groupby('Cuisines').mean().sort_values('Aggregate rating', ascending = False)
#       9 #df_aux
#
# File c:\Users\Antonio Richard\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:818, in _LocationIndexer.__setitem__(self, key, value)
#     815 self._has_valid_setitem_indexer(key)
#     817 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 818 iloc._setitem_with_indexer(indexer, value, self.name)
#
# ...

# %%
df1
# Out:
#                      Cuisines  Aggregate rating
# 0  [Italian, European, Asian]               4.9
# 1           [Indian, Mexican]               3.5
# 2                   [Chinese]               4.2

# %%
df_exploded = df1.explode('Cuisines')

# %%
df_exploded
# Out:
#    Cuisines  Aggregate rating
# 0   Italian               4.9
# 0  European               4.9
# 0     Asian               4.9
# 1    Indian               3.5
# 1   Mexican               3.5
# 2   Chinese               4.2

# %%
import pandas as pd

# Exemplo de DataFrame
data = {'Cuisines': ['Italian, European, Asian', 'Indian, Mexican', 'Chinese'],
        'Aggregate rating': [4.9, 3.5, 4.2]}

df2 = pd.DataFrame(data)
df2
# Out:
#                    Cuisines  Aggregate rating
# 0  Italian, European, Asian               4.9
# 1           Indian, Mexican               3.5
# 2                   Chinese               4.2

# %%
df2['Cuisines'] = df2['Cuisines'].str.split(', ')
df2
# Out:
#                      Cuisines  Aggregate rating
# 0  [Italian, European, Asian]               4.9
# 1           [Indian, Mexican]               3.5
# 2                   [Chinese]               4.2

# %%
df_exploded = df2.explode('Cuisines')

# %%
df_exploded
# Out:
#    Cuisines  Aggregate rating
# 0   Italian               4.9
# 0  European               4.9
# 0     Asian               4.9
# 1    Indian               3.5
# 1   Mexican               3.5
# 2   Chinese               4.2

# %% [markdown]
# # Perguntas

# %% [markdown]
# ## Gerais

# %% [markdown]
# 1. Quantos restaurantes únicos estão registrados?

# %%
df['Restaurant ID'].nunique()
# Out:
# 6942

# %%
len(df['Restaurant ID'].unique())
# Out:
# 6942

# %% [markdown]
# 2. Quantos países únicos estão registrados?

# %%
df['Country Code'].nunique()
# Out:
# 15

# %% [markdown]
# 3. Quantas cidades únicas estão registradas?

# %%
df['City'].nunique()
# Out:
# 125

# %% [markdown]
# 4. Qual o total de avaliações feitas?

# %%
df['Aggregate rating'].count()
# Out:
# 7527

# %% [markdown]
# 5. Qual o total de tipos de culinária registrados?

# %%
df['Cuisines'].nunique()
# Out:
# 2832

# %% [markdown]
# ## Pais

# %% [markdown]
# 1. Qual o nome do país que possui mais cidades registradas?

# %%
df.loc[:, ['Country_id' , 'City' ]].groupby('Country_id').count().reset_index().sort_values('City', ascending = False)
# Out:
#                   Country_id  City
# 4                      India  3507
# 14  United States of America  1395
# 3                    England   437
# 10              South Africa   382
# 13      United Arab Emirates   334
# 1                     Brazil   261
# 6                 New Zeland   253
# 0                  Australia   180
# 2                     Canada   180
# 12                    Turkey   165
# 8                      Qatar    94
# 7                Philippines    88
# 11                 Sri Lanka    87
# 5                  Indonesia    82
# 9                  Singapure    82

# %% [markdown]
# 2. Qual o nome do país que possui mais restaurantes registrados?

# %%
df.loc[:, ['Country_id', 'Restaurant Name' ]].groupby('Country_id').count().reset_index().sort_values('Restaurant Name', ascending = False)
# Out:
#                   Country_id  Restaurant Name
# 4                      India             3507
# 14  United States of America             1395
# 3                    England              437
# 10              South Africa              382
# 13      United Arab Emirates              334
# 1                     Brazil              261
# 6                 New Zeland              253
# 0                  Australia              180
# 2                     Canada              180
# 12                    Turkey              165
# 8                      Qatar               94
# 7                Philippines               88
# 11                 Sri Lanka               87
# 5                  Indonesia               82
# 9                  Singapure               82

# %% [markdown]
# 3. Qual o nome do país que possui mais restaurantes com o nível de preço igual a 4
# registrados?

# %%
filtro = df['Price range'] == 4
df.loc[filtro,['Country_id', 'Restaurant Name']].groupby('Country_id').count().reset_index().sort_values('Restaurant Name', ascending = False)
# Out:
#                   Country_id  Restaurant Name
# 14  United States of America              420
# 10              South Africa              237
# 4                      India              210
# 1                     Brazil              159
# 13      United Arab Emirates              122
# 3                    England               83
# 6                 New Zeland               81
# 8                      Qatar               63
# 12                    Turkey               62
# 9                  Singapure               59
# 2                     Canada               54
# 0                  Australia               33
# 7                Philippines               23
# 5                  Indonesia               18
# 11                 Sri Lanka               18

# %% [markdown]
# 4. Qual o nome do país que possui a maior quantidade de tipos de culinária
# distintos?

# %%
df.loc[:,['Country_id', 'Cuisines']].groupby('Country_id').count().reset_index().sort_values('Cuisines', ascending = False)
# Out:
#                   Country_id  Cuisines
# 4                      India      3496
# 14  United States of America      1391
# 3                    England       437
# 10              South Africa       382
# 13      United Arab Emirates       334
# 1                     Brazil       261
# 6                 New Zeland       253
# 0                  Australia       180
# 2                     Canada       180
# 12                    Turkey       165
# 8                      Qatar        94
# 7                Philippines        88
# 11                 Sri Lanka        87
# 5                  Indonesia        82
# 9                  Singapure        82

# %% [markdown]
# 5. Qual o nome do país que possui a maior quantidade de avaliações feitas?

# %%
df.loc[:, ['Country_id','Aggregate rating' ]].groupby('Country_id').count().reset_index().sort_values('Aggregate rating', ascending = False)
# Out:
#                   Country_id  Aggregate rating
# 4                      India              3507
# 14  United States of America              1395
# 3                    England               437
# 10              South Africa               382
# 13      United Arab Emirates               334
# 1                     Brazil               261
# 6                 New Zeland               253
# 0                  Australia               180
# 2                     Canada               180
# 12                    Turkey               165
# 8                      Qatar                94
# 7                Philippines                88
# 11                 Sri Lanka                87
# 5                  Indonesia                82
# 9                  Singapure                82

# %% [markdown]
# 6. Qual o nome do país que possui a maior quantidade de restaurantes que fazem
# entrega?

# %%
filtro = df['Is delivering now'] == 1
df.loc[filtro,['Country_id', 'Restaurant ID'] ].groupby('Country_id').count().reset_index().sort_values('Restaurant ID', ascending = False)
# Out:
#              Country_id  Restaurant ID
# 0                 India           1247
# 3  United Arab Emirates             55
# 1           Philippines              7
# 2                 Qatar              3

# %% [markdown]
# 7. Qual o nome do país que possui a maior quantidade de restaurantes que aceitam
# reservas?

# %%
filtro  = df['Has Table booking'] == 1
df.loc[filtro, ['Country_id', 'Restaurant ID']].groupby('Country_id').count().reset_index().sort_values('Restaurant ID', ascending  = False)
# Out:
#                   Country_id  Restaurant ID
# 2                      India            291
# 1                    England             58
# 0                  Australia             29
# 5                Philippines             28
# 4                 New Zeland             19
# 3                  Indonesia             14
# 10      United Arab Emirates             12
# 6                      Qatar              5
# 9                     Turkey              5
# 7               South Africa              3
# 11  United States of America              3
# 8                  Sri Lanka              1

# %% [markdown]
# 8. Qual o nome do país que possui, na média, a maior quantidade de avaliações
# registrada?

# %%
df.loc[:, ['Country_id', 'Aggregate rating']].groupby('Country_id').count().reset_index().sort_values('Aggregate rating', ascending  = False)
# Out:
#                   Country_id  Aggregate rating
# 4                      India              3507
# 14  United States of America              1395
# 3                    England               437
# 10              South Africa               382
# 13      United Arab Emirates               334
# 1                     Brazil               261
# 6                 New Zeland               253
# 0                  Australia               180
# 2                     Canada               180
# 12                    Turkey               165
# 8                      Qatar                94
# 7                Philippines                88
# 11                 Sri Lanka                87
# 5                  Indonesia                82
# 9                  Singapure                82

# %% [markdown]
# 9. Qual o nome do país que possui, na média, a maior nota média registrada?

# %%
df.loc[:, ['Country_id', 'Aggregate rating']].groupby('Country_id').mean().reset_index().sort_values('Aggregate rating', ascending  = False)
# Out:
#                   Country_id  Aggregate rating
# 5                  Indonesia          4.600000
# 7                Philippines          4.462500
# 9                  Singapure          4.429268
# 14  United States of America          4.404659
# 0                  Australia          4.372778
# 2                     Canada          4.321667
# 12                    Turkey          4.313939
# 8                      Qatar          4.267021
# 6                 New Zeland          4.166798
# 11                 Sri Lanka          4.070115
# 13      United Arab Emirates          4.055689
# 10              South Africa          4.054188
# 3                    England          4.041190
# 4                      India          4.017479
# 1                     Brazil          3.349425

# %% [markdown]
# 10. Qual o nome do país que possui, na média, a menor nota média registrada?

# %%
df.loc[:, ['Country_id', 'Aggregate rating']].groupby('Country_id').mean().reset_index().sort_values('Aggregate rating', ascending  = True)
# Out:
#                   Country_id  Aggregate rating
# 1                     Brazil          3.349425
# 4                      India          4.017479
# 3                    England          4.041190
# 10              South Africa          4.054188
# 13      United Arab Emirates          4.055689
# 11                 Sri Lanka          4.070115
# 6                 New Zeland          4.166798
# 8                      Qatar          4.267021
# 12                    Turkey          4.313939
# 2                     Canada          4.321667
# 0                  Australia          4.372778
# 14  United States of America          4.404659
# 9                  Singapure          4.429268
# 7                Philippines          4.462500
# 5                  Indonesia          4.600000

# %% [markdown]
# 11. Qual a média de preço de um prato para dois por país?

# %%
df.loc[:, ['Country_id','Average Cost for two']].groupby('Country_id').mean().reset_index().sort_values('Average Cost for two', ascending = False)
# Out:
#                   Country_id  Average Cost for two
# 5                  Indonesia         312682.926829
# 0                  Australia         138959.783333
# 11                 Sri Lanka           2607.471264
# 7                Philippines           1211.090909
# 4                      India            702.303964
# 10              South Africa            335.479058
# 8                      Qatar            176.648936
# 13      United Arab Emirates            158.218563
# 9                  Singapure            141.036585
# 1                     Brazil            137.375479
# 12                    Turkey            128.848485
# 6                 New Zeland             61.442688
# 14  United States of America             54.921864
# 3                    England             43.045767
# 2                     Canada             41.861111

# %% [markdown]
# ## Cidade

# %% [markdown]
# 1. Qual o nome da cidade que possui mais restaurantes registrados?

# %%
df.head(2)
df.loc[:,['Restaurant ID', 'City']].groupby('City').count().reset_index().sort_values('Restaurant ID', ascending = False)
# Out:
#                 City  Restaurant ID
# 76            Nagpur             99
# 111            Surat             95
# 14        Birmingham             95
# 0          Abu Dhabi             95
# 32              Doha             94
# ..               ...            ...
# 40         Ghaziabad              1
# 74   Muntinlupa City              1
# 68     Marikina City              1
# 123         Zirakpur              1
# 38       Gandhinagar              1
#
# [125 rows x 2 columns]

# %% [markdown]
# 2. Qual o nome da cidade que possui mais restaurantes com nota média acima de
# 4?

# %%
filtro = df['Aggregate rating']> 4
df.loc[filtro,['Country_id','City', 'Restaurant ID']].groupby(['City', 'Country_id']).count().reset_index().sort_values('Restaurant ID', ascending = False)
# Out:
#                 City                Country_id  Restaurant ID
# 11         Bangalore                     India             86
# 43           Houston  United States of America             82
# 23           Chennai                     India             82
# 56            London                   England             81
# 53           Kolkata                     India             80
# ..               ...                       ...            ...
# 96        Roodepoort              South Africa              1
# 37         Ghaziabad                     India              1
# 75             Nasik                     India              1
# 119         Zirakpur                     India              1
# 71   Muntinlupa City               Philippines              1
#
# [121 rows x 3 columns]

# %% [markdown]
# 3. Qual o nome da cidade que possui mais restaurantes com nota média abaixo de
# 2.5?

# %%
filtro = df['Aggregate rating']< 2.5
df.loc[filtro,['Country_id','City', 'Restaurant ID']].groupby(['City', 'Country_id']).count().reset_index().sort_values('Restaurant ID', ascending = False)
# Out:
#               City    Country_id  Restaurant ID
# 6          Gangtok         India             47
# 10            Ooty         India             22
# 16       São Paulo        Brazil             17
# 1         Brasília        Brazil             15
# 14  Rio de Janeiro        Brazil             13
# 8       Manchester       England              7
# 2          Clarens  South Africa              4
# 15          Shimla         India              4
# 13      Puducherry         India              3
# 5        Edinburgh       England              2
# 7         Hamilton    New Zeland              2
# 12        Pretoria  South Africa              2
# 4           Durban  South Africa              1
# 9           Nashik         India              1
# 3          Colombo     Sri Lanka              1
# 11           Perth     Australia              1
# 0           Ankara        Turkey              1

# %% [markdown]
# 4. Qual o nome da cidade que possui o maior valor médio de um prato para dois?

# %%
df.loc[filtro,['Country_id','City', 'Average Cost for two']].groupby(['City', 'Country_id']).mean().reset_index().sort_values('Average Cost for two', ascending = False)
# Out:
#               City    Country_id  Average Cost for two
# 3          Colombo     Sri Lanka           2500.000000
# 13      Puducherry         India            760.000000
# 4           Durban  South Africa            450.000000
# 12        Pretoria  South Africa            450.000000
# 6          Gangtok         India            423.404255
# 9           Nashik         India            300.000000
# 10            Ooty         India            284.090909
# 2          Clarens  South Africa            282.500000
# 14  Rio de Janeiro        Brazil            135.769231
# 1         Brasília        Brazil             90.000000
# 16       São Paulo        Brazil             87.941176
# 11           Perth     Australia             70.000000
# 7         Hamilton    New Zeland             67.500000
# 0           Ankara        Turkey             60.000000
# 15          Shimla         India             37.500000
# 8       Manchester       England             21.428571
# ...

# %% [markdown]
# 5. Qual o nome da cidade que possui a maior quantidade de tipos de culinária
# distintas?

# %%
df.loc[:, ['City', 'Cuisines', 'Country_id']].groupby(['City', 'Country_id']).count().reset_index().sort_values('Cuisines', ascending = False)
# Out:
#               City            Country_id  Cuisines
# 76          Nagpur                 India        99
# 111          Surat                 India        95
# 14      Birmingham               England        95
# 0        Abu Dhabi  United Arab Emirates        95
# 32            Doha                 Qatar        94
# ..             ...                   ...       ...
# 40       Ghaziabad                 India         1
# 38     Gandhinagar                 India         1
# 104  San Juan City           Philippines         1
# 100     Roodepoort          South Africa         1
# 123       Zirakpur                 India         1
#
# [125 rows x 3 columns]

# %% [markdown]
# 6. Qual o nome da cidade que possui a maior quantidade de restaurantes que fazem
# reservas?

# %%
df.loc[:, ['Country_id','City', 'Has Table booking']].groupby(['City', 'Country_id']).count().reset_index().sort_values('Has Table booking', ascending = False)
# Out:
#                 City            Country_id  Has Table booking
# 76            Nagpur                 India                 99
# 111            Surat                 India                 95
# 14        Birmingham               England                 95
# 0          Abu Dhabi  United Arab Emirates                 95
# 32              Doha                 Qatar                 94
# ..               ...                   ...                ...
# 40         Ghaziabad                 India                  1
# 74   Muntinlupa City           Philippines                  1
# 68     Marikina City           Philippines                  1
# 123         Zirakpur                 India                  1
# 38       Gandhinagar                 India                  1
#
# [125 rows x 3 columns]

# %% [markdown]
# 7. Qual o nome da cidade que possui a maior quantidade de restaurantes que fazem
# entregas?

# %%
df.loc[:, ['Country_id', 'City', 'Is delivering now']].groupby(['City','Country_id', ]).count().reset_index().sort_values('Is delivering now', ascending = False)
# Out:
#                 City            Country_id  Is delivering now
# 76            Nagpur                 India                 99
# 111            Surat                 India                 95
# 14        Birmingham               England                 95
# 0          Abu Dhabi  United Arab Emirates                 95
# 32              Doha                 Qatar                 94
# ..               ...                   ...                ...
# 40         Ghaziabad                 India                  1
# 74   Muntinlupa City           Philippines                  1
# 68     Marikina City           Philippines                  1
# 123         Zirakpur                 India                  1
# 38       Gandhinagar                 India                  1
#
# [125 rows x 3 columns]

# %% [markdown]
# 8. Qual o nome da cidade que possui a maior quantidade de restaurantes que
# aceitam pedidos online?

# %%
df.loc[:, ['Country_id', 'City', 'Has Online delivery']].groupby(['City', 'Country_id' ]).count().reset_index().sort_values('Has Online delivery', ascending = False)
# Out:
#                 City            Country_id  Has Online delivery
# 76            Nagpur                 India                   99
# 111            Surat                 India                   95
# 14        Birmingham               England                   95
# 0          Abu Dhabi  United Arab Emirates                   95
# 32              Doha                 Qatar                   94
# ..               ...                   ...                  ...
# 40         Ghaziabad                 India                    1
# 74   Muntinlupa City           Philippines                    1
# 68     Marikina City           Philippines                    1
# 123         Zirakpur                 India                    1
# 38       Gandhinagar                 India                    1
#
# [125 rows x 3 columns]

# %% [markdown]
# ## Restaurants

# %% [markdown]
# 1. Qual o nome do restaurante que possui a maior quantidade de avaliações?

# %%
df.loc[:,['Restaurant Name', 'Aggregate rating']].groupby('Restaurant Name').count().reset_index().sort_values('Aggregate rating', ascending= False)
# Out:
#                    Restaurant Name  Aggregate rating
# 1522                Domino's Pizza               204
# 2600                           KFC                51
# 3905                     Pizza Hut                40
# 3219                    McDonald's                36
# 455                Barbeque Nation                32
# ...                            ...               ...
# 2088                          Grub                 1
# 2087              Grounded at Echo                 1
# 2086  Grizzly Peak Brewing Company                 1
# 2083                  Grillfish DC                 1
# 5903             ह-tea The Tea Hut                 1
#
# [5904 rows x 2 columns]

# %% [markdown]
# 2. Qual o nome do restaurante com a maior nota média?

# %%
df.loc[:,['Country_id','City','Restaurant Name', 'Aggregate rating']].groupby([ 'Restaurant Name','Country_id','City']).mean().reset_index().sort_values('Aggregate rating', ascending= False)
# Out:
#                          Restaurant Name                Country_id  \
# 1446                        Corner House                 Singapure
# 5639                      The Halal Guys  United States of America
# 5777                    The Potluck Club              South Africa
# 5779  The Public House Café n Restaurant                     India
# 1339                 Churrascaria Palace                    Brazil
# ...                                  ...                       ...
# 1515                        DX Fast Food                     India
# 4473                               Raful                    Brazil
# 5356                  Tempero das Gerais                    Brazil
# 2715                     Jain Restaurant                     India
# 5029                Snow Lion Restaurant                     India
#
#                 City  Aggregate rating
# 1446       Singapore               4.9
# 5639   New York City               4.9
# 5777       Cape Town               4.9
# ...

# %% [markdown]
# 3. Qual o nome do restaurante que possui o maior valor de uma prato para duas
# pessoas?

# %%
df.loc[:,['Country_id','City','Restaurant Name', 'Average Cost for two']].groupby([ 'Restaurant Name','Country_id','City']).max().reset_index().sort_values('Average Cost for two', ascending= False)
# Out:
#                    Restaurant Name                Country_id       City  \
# 6430  d'Arry's Verandah Restaurant                 Australia   Adelaide
# 5477        The Café - Hotel Mulia                 Indonesia    Jakarta
# 2092          GIA Restaurant & Bar                 Indonesia    Jakarta
# 4693                          SKYE                 Indonesia    Jakarta
# 4863           Shabu-Shabu Shaburi                 Indonesia    Jakarta
# ...                            ...                       ...        ...
# 3167                       Le Bife                    Brazil  São Paulo
# 3354                        Madero                    Brazil   Brasília
# 176                 Alden & Harlow  United States of America     Boston
# 4592                  Ristorantino                    Brazil  São Paulo
# 5391              The Albion Rooms                    Canada     Ottawa
#
#       Average Cost for two
# 6430              25000017
# 5477               1200000
# ...

# %% [markdown]
# 4. Qual o nome do restaurante de tipo de culinária brasileira que possui a menor
# média de avaliação? (TEM O ERRO, N USEI A FUNÇÃO)

# %%
filtro =df['Cuisines'] == 'Brazil'
df.loc[:, ['Cuisines','Restaurant Name', 'Aggregate rating']].groupby(['Cuisines','Restaurant Name']).min().reset_index().sort_values('Aggregate rating', ascending=True)
# Out:
#                                                Cuisines      Restaurant Name  \
# 0     Afghan, Asian, BBQ, Chinese, Fast Food, Finger...  Republic of Chicken
# 3458                                            Italian         Ristorantino
# 748                                              Bakery     New Aazam Bakery
# 749                                              Bakery     New Aleef Bakery
# 754                                              Bakery             Tripti's
# ...                                                 ...                  ...
# 3151          Ice Cream, Desserts, Beverages, Fast Food               Pabbas
# 3209                                             Indian            The Delhi
# 3213                                             Indian     Yew Tree Cottage
# 6119                                     Tapas, Spanish     The Harvest Vine
# 3284                  Indian, North Indian, Curry, Cafe              Dishoom
#
#       Aggregate rating
# ...

# %% [markdown]
# 5. Qual o nome do restaurante de tipo de culinária brasileira, e que é do Brasil, que
# possui a maior média de avaliação?

# %% [markdown]
# 6. Os restaurantes que aceitam pedido online são também, na média, os
# restaurantes que mais possuem avaliações registradas?

# %%
#Os aceitam pedido online
#Os os que não aceitam

#Quantidade de avaliações registradas

# %%
df.loc[:,['Restaurant ID','Has Online delivery',  'Aggregate rating']].groupby('Has Online delivery').count().reset_index()
# Out:
#    Has Online delivery  Restaurant ID  Aggregate rating
# 0                    0           4874              4874
# 1                    1           2653              2653

# %% [markdown]
# 7. Os restaurantes que fazem reservas são também, na média, os restaurantes que
# possuem o maior valor médio de um prato para duas pessoas?

# %%
# Os restaurantes que fazem 
# Reservas
# São o que mais possuiur valor médio por prato
df.loc[:,[ 'Has Table booking', 'Average Cost for two']].groupby('Has Table booking').mean().reset_index()
# Out:
#    Has Table booking  Average Cost for two
# 0                  0           3454.031591
# 1                  1          62931.512821

# %% [markdown]
# 8. Os restaurantes do tipo de culinária japonesa dos Estados Unidos da América
# possuem um valor médio de prato para duas pessoas maior que as churrascarias
# americanas (BBQ)?

# %%
# Fitro country == EUA and culinária == 'Sushi, Japanese' or country == EUA and culinária == BBQ
# Colunas 'Country_id', 'Cuisines'

# %%
filtro = df['Country_id'].str.contains('United States of America') & df['Cuisines'].str.contains('BBQ') | df['Country_id'].str.contains('United States of America') & df['Cuisines'].str.contains('Japanese') 
df.loc[filtro, ['Country_id', 'Cuisines','Average Cost for two']].groupby(['Country_id', 'Cuisines']).mean().sort_values('Average Cost for two', ascending=False)
# Out:
#                                                                              Average Cost for two
# Country_id               Cuisines
# United States of America Asian, Chinese, Japanese                                      150.000000
#                          Asian, Japanese, Sushi                                         87.500000
#                          American, Southwestern, BBQ                                    85.000000
#                          Japanese, Steak, Sushi                                         82.500000
#                          Peruvian, Japanese, Fusion                                     80.000000
#                          BBQ, Breakfast, Southern                                       75.000000
#                          Japanese, Sushi                                                70.588235
#                          American, BBQ                                                  65.000000
# ...

# %% [markdown]
# # Tipos de Culinária

# %% [markdown]
# 1. Dos restaurantes que possuem o tipo de culinária italiana, qual o nome do
# restaurante com a maior média de avaliação?

# %%
receba =df['Cuisines'].str.contains('Italian')

# %%
df.loc[receba != False,['Country_id', 'City','Restaurant Name', 'Aggregate rating'] ].groupby(['Restaurant Name','Country_id', 'City']).mean().reset_index().sort_values('Aggregate rating', ascending= False)
# Out:
#                   Restaurant Name                Country_id         City  \
# 159               Central Grocery  United States of America  New Orleans
# 601               Regina Pizzeria  United States of America       Boston
# 34   Andre's Cucina & Polenta Bar                 Australia     Adelaide
# 765           The Parlor Pizzeria  United States of America      Phoenix
# 158                      Celino's                   England      Glasgow
# ..                            ...                       ...          ...
# 45               Avenida Paulista                    Brazil     Brasília
# 667           Sonny's​ Oasis Cafe                     India      Gangtok
# 285             Fusion Restaurant                     India      Gangtok
# 610                  Ristorantino                    Brazil    São Paulo
# 767             The Pasta Factory                   England   Manchester
#
#      Aggregate rating
# 159               4.9
# 601               4.9
# ...

# %% [markdown]
# 2. Dos restaurantes que possuem o tipo de culinária italiana, qual o nome do
# restaurante com a menor média de avaliação?

# %%
df.loc[receba != False,['Country_id', 'City','Restaurant Name', 'Aggregate rating'] ].groupby(['Restaurant Name','Country_id', 'City']).mean().reset_index().sort_values('Aggregate rating', ascending= True)
# Out:
#                   Restaurant Name                Country_id             City  \
# 644            Seasons Restaurant                     India             Ooty
# 810        Unique Sweets & Snacks                     India          Gangtok
# 223         Doma Restaurant & Bar                     India          Gangtok
# 63       Basement Lounge & Bistro                     India          Gangtok
# 285             Fusion Restaurant                     India          Gangtok
# ..                            ...                       ...              ...
# 601               Regina Pizzeria  United States of America           Boston
# 34   Andre's Cucina & Polenta Bar                 Australia         Adelaide
# 303                   Guillermo's  United States of America      San Antonio
# 27               Amano Restaurant                New Zeland         Auckland
# 487                         Ombra                New Zeland  Wellington City
#
#      Aggregate rating
# ...

# %% [markdown]
# 3. Dos restaurantes que possuem o tipo de culinária americana, qual o nome do
# restaurante com a maior média de avaliação?

# %%
filtro = df['Cuisines'].str.contains('American')
df.loc[filtro != False,['Country_id','City','Restaurant Name', 'Aggregate rating']].groupby(['Restaurant Name','Country_id','City']).mean().reset_index().sort_values('Aggregate rating', ascending = False)
# Out:
#             Restaurant Name                Country_id        City  \
# 378  Lafayette Coney Island  United States of America     Detroit
# 731              Wild Honey                 Singapure   Singapore
# 233                 Fat Cat  United States of America      Boston
# 475             Park Burger  United States of America      Denver
# 488     Portillo's Hot Dogs  United States of America     Chicago
# ..                      ...                       ...         ...
# 708  Unique Sweets & Snacks                     India     Gangtok
# 207   Doma Restaurant & Bar                     India     Gangtok
# 561     Sonny's​ Oasis Cafe                     India     Gangtok
# 540         Seekhs & Kebabs                     India     Gangtok
# 25        Alston Bar & Beef                   England  Manchester
#
#      Aggregate rating
# 378               4.9
# 731               4.9
# 233               4.9
# 475               4.9
# 488               4.9
# ..                ...
# ...

# %% [markdown]
# 4. Dos restaurantes que possuem o tipo de culinária americana, qual o nome do
# restaurante com a menor média de avaliação?

# %%
filtro = df['Cuisines'].str.contains('American')
df.loc[filtro != False,['Country_id','City','Restaurant Name', 'Aggregate rating']].groupby(['Restaurant Name','Country_id','City']).mean().reset_index().sort_values('Aggregate rating', ascending = True)
# Out:
#               Restaurant Name                Country_id       City  \
# 561       Sonny's​ Oasis Cafe                     India    Gangtok
# 330           Hotel Dongkhela                     India    Gangtok
# 540           Seekhs & Kebabs                     India    Gangtok
# 64   Basement Lounge & Bistro                     India    Gangtok
# 256         Fusion Restaurant                     India    Gangtok
# ..                        ...                       ...        ...
# 488       Portillo's Hot Dogs  United States of America    Chicago
# 56            Barbeque Nation                     India      Kochi
# 369     Kono's Surf Club Cafe  United States of America  San Diego
# 658           The Observatory  United States of America   Portland
# 194      Cut By Wolfgang Puck                 Singapure  Singapore
#
#      Aggregate rating
# 561               0.0
# 330               0.0
# 540               0.0
# 64                0.0
# 256               0.0
# ...

# %% [markdown]
# 5. Dos restaurantes que possuem o tipo de culinária árabe, qual o nome do
# restaurante com a maior média de avaliação?

# %%
#Filtro
filtro = df['Cuisines'].str.contains('Arabian')
df.loc[filtro != False, ['Restaurant Name','Aggregate rating', 'City', 'Country_id' ]].groupby(['Restaurant Name', 'City', 'Country_id' ]).mean().reset_index().sort_values('Aggregate rating', ascending= False)
# Arabian
# Out:
#                    Restaurant Name          City            Country_id  \
# 29                  Coal Barbecues       Chennai                 India
# 18                 Barbeque Nation  Bhubaneshwar                 India
# 51                        Mandi@36     Hyderabad                 India
# 45  Kitchen6 - JW Marriott Marquis         Dubai  United Arab Emirates
# 19                 Barbeque Nation        Kanpur                 India
# ..                             ...           ...                   ...
# 40                 Hotel Dongkhela       Gangtok                 India
# 32           Doma Restaurant & Bar       Gangtok                 India
# 61                           Raful     São Paulo                Brazil
# 72             Sonny's​ Oasis Cafe       Gangtok                 India
# 68                 Seekhs & Kebabs       Gangtok                 India
#
#     Aggregate rating
# 29               4.9
# 18               4.9
# 51               4.7
# 45               4.7
# ...

# %% [markdown]
# 6. Dos restaurantes que possuem o tipo de culinária árabe, qual o nome do
# restaurante com a menor média de avaliação?

# %%
#Filtro
filtro = df['Cuisines'].str.contains('Arabian')
df.loc[filtro != False, ['Restaurant Name','Aggregate rating', 'City', 'Country_id' ]].groupby(['Restaurant Name', 'City', 'Country_id' ]).mean().reset_index().sort_values('Aggregate rating', ascending= True)
# Arabian
# Out:
#                    Restaurant Name          City            Country_id  \
# 72             Sonny's​ Oasis Cafe       Gangtok                 India
# 32           Doma Restaurant & Bar       Gangtok                 India
# 20        Basement Lounge & Bistro       Gangtok                 India
# 37               Fusion Restaurant       Gangtok                 India
# 40                 Hotel Dongkhela       Gangtok                 India
# ..                             ...           ...                   ...
# 42           ILA Restaurant & Cafe         Dubai  United Arab Emirates
# 51                        Mandi@36     Hyderabad                 India
# 45  Kitchen6 - JW Marriott Marquis         Dubai  United Arab Emirates
# 29                  Coal Barbecues       Chennai                 India
# 18                 Barbeque Nation  Bhubaneshwar                 India
#
#     Aggregate rating
# 72               0.0
# 32               0.0
# 20               0.0
# 37               0.0
# ...

# %% [markdown]
# 7. Dos restaurantes que possuem o tipo de culinária japonesa, qual o nome do
# restaurante com a maior média de avaliação?

# %%
# 'Sushi, Japanese'
Filtro = df['Cuisines'].str.contains('Japanese') # & df['Cuisines'].str.contains('Sushi')
df.loc[Filtro != False, ['Cuisines', 'Restaurant Name', 'Aggregate rating', 'City', 'Country_id'] ].groupby(['Restaurant Name','Cuisines',  'Country_id', 'City']).mean().reset_index().sort_values('Aggregate rating', ascending = False )
# Out:
#            Restaurant Name                                           Cuisines  \
# 125                   Ooma                                    Japanese, Sushi
# 87       Mendokoro Ramenba                                    Japanese, Ramen
# 68                    Kazu                               Asian, BBQ, Japanese
# 139         Ramen Yushoken                                    Japanese, Ramen
# 115             Nobu Perth                                    Japanese, Sushi
# ..                     ...                                                ...
# 127              Orienthai                              Japanese, Thai, Asian
# 109                 Nippon                                    Sushi, Japanese
# 118                   Nosu                                    Sushi, Japanese
# 198  Tanka - Hotel Akasaka  Asian, Japanese, Thai, Korean, Brazilian, Chinese
# 7             Banzai Sushi                                           Japanese
#
# ...

# %% [markdown]
# 8. Dos restaurantes que possuem o tipo de culinária japonesa, qual o nome do
# restaurante com a menor média de avaliação?

# %%
# 'Sushi, Japanese'
Filtro = df['Cuisines'].str.contains('Japanese') # & df['Cuisines'].str.contains('Sushi')
df.loc[Filtro != False, ['Cuisines', 'Restaurant Name', 'Aggregate rating', 'City', 'Country_id'] ].groupby(['Restaurant Name','Cuisines',  'Country_id', 'City']).mean().reset_index().sort_values('Aggregate rating', ascending = True )
# Out:
#               Restaurant Name  \
# 109                    Nippon
# 118                      Nosu
# 7                Banzai Sushi
# 198     Tanka - Hotel Akasaka
# 127                 Orienthai
# ..                        ...
# 188              Sushi Leblon
# 217  WAKI Japanese BBQ Dining
# 68                       Kazu
# 87          Mendokoro Ramenba
# 111                Noble Fish
#
#                                               Cuisines  \
# 109                                    Sushi, Japanese
# 118                                    Sushi, Japanese
# 7                                             Japanese
# 198  Asian, Japanese, Thai, Korean, Brazilian, Chinese
# 127                              Japanese, Thai, Asian
# ..                                                 ...
# 188                                           Japanese
# 217                Japanese, Grill, BBQ, Korean, Asian
# 68                                Asian, BBQ, Japanese
# ...

# %% [markdown]
# 9. Dos restaurantes que possuem o tipo de culinária caseira, qual o nome do
# restaurante com a maior média de avaliação?

# %%
Filtro = df['Cuisines'].str.contains('Home-made')
df.loc[Filtro != False,['Cuisines', 'City', 'Country_id', 'Restaurant Name', 'Aggregate rating']].groupby(['Restaurant Name','Cuisines', 'City', 'Country_id'  ]).mean().reset_index().sort_values('Aggregate rating', ascending = False )
# Out:
#        Restaurant Name                         Cuisines      City Country_id  \
# 1               Fıccın      Old Turkish Bars, Home-made  İstanbul     Turkey
# 4              Sarıhan       Giblets, Izgara, Home-made  İstanbul     Turkey
# 0   Evvel Türk Mutfağı  Steak, Turkish Pizza, Home-made  İstanbul     Turkey
# 3     Kanaat Lokantası                Home-made, Izgara  İstanbul     Turkey
# 2  GurMekan Restaurant                        Home-made    Ankara     Turkey
#
#    Aggregate rating
# 1               4.7
# 4               4.4
# 0               4.0
# 3               4.0
# 2               3.7

# %% [markdown]
# 10. Dos restaurantes que possuem o tipo de culinária caseira, qual o nome do
# restaurante com a menor média de avaliação?

# %%
Filtro = df['Cuisines'].str.contains('Home-made')
df.loc[Filtro != False,['Cuisines', 'City', 'Country_id', 'Restaurant Name', 'Aggregate rating']].groupby(['Restaurant Name','Cuisines', 'City', 'Country_id'  ]).mean().reset_index().sort_values('Aggregate rating', ascending = True )
# Out:
#        Restaurant Name                         Cuisines      City Country_id  \
# 2  GurMekan Restaurant                        Home-made    Ankara     Turkey
# 0   Evvel Türk Mutfağı  Steak, Turkish Pizza, Home-made  İstanbul     Turkey
# 3     Kanaat Lokantası                Home-made, Izgara  İstanbul     Turkey
# 4              Sarıhan       Giblets, Izgara, Home-made  İstanbul     Turkey
# 1               Fıccın      Old Turkish Bars, Home-made  İstanbul     Turkey
#
#    Aggregate rating
# 2               3.7
# 0               4.0
# 3               4.0
# 4               4.4
# 1               4.7

# %% [markdown]
# 11. Qual o tipo de culinária que possui o maior valor médio de um prato para duas pessoas?

# %%
# Qual 'Average Cost for two','Cuisines', 'Country_id', 'City', 'Restaurant Name'

df.loc [:,['Average Cost for two','Cuisines', 'Country_id', 'City', 'Restaurant Name'] ].groupby(['Cuisines', 'Country_id', 'City', 'Restaurant Name']).mean().reset_index().sort_values('Average Cost for two', ascending = False)
# Out:
#                                                Cuisines  \
# 4437                      Modern Australian, Australian
# 649                          Asian, Indonesian, Western
# 3544                                            Italian
# 678                                        Asian, Steak
# 3895                                           Japanese
# ...                                                 ...
# 185                                 American, Breakfast
# 51                                             American
# 1994                                            Chinese
# 5932                                     Seafood, Sushi
# 0     Afghan, Asian, BBQ, Chinese, Fast Food, Finger...
#
#                     Country_id       City                 Restaurant Name  \
# 4437                 Australia   Adelaide    d'Arry's Verandah Restaurant
# 649                  Indonesia    Jakarta          The Café - Hotel Mulia
# ...

# %% [markdown]
# 12. Qual o tipo de culinária que possui a maior nota média?

# %%
df.loc[:,['Cuisines','Aggregate rating', 'Country_id', 'City', 'Restaurant Name']].groupby(['Cuisines', 'Country_id', 'City', 'Restaurant Name']).mean().reset_index().sort_values('Aggregate rating', ascending= False)
# Out:
#                                                Cuisines  \
# 169                        American, Bar Food, Pub Food
# 6504                                         Vietnamese
# 3550                                            Italian
# 2705                  European, Spanish, American, Cafe
# 3545                                            Italian
# ...                                                 ...
# 3734                                     Italian, Pizza
# 3865                                           Japanese
# 940                      Biryani, Chinese, North Indian
# 6369                                                Tea
# 0     Afghan, Asian, BBQ, Chinese, Fast Food, Finger...
#
#                     Country_id             City  \
# 169   United States of America          Atlanta
# 6504                   England        Edinburgh
# 3550                New Zeland  Wellington City
# 2705                 Singapure        Singapore
# ...

# %% [markdown]
# 13. Qual o tipo de culinária que possui mais restaurantes que aceitam pedidos
# online e fazem entregas?

# %%
#   'Cuisines', 'Has Online delivery', 'Is delivering now' ,'Country_id', 'City'
#                   SAPE
# OUTPUT  - > A culinária que mais é pedida online e entregada
# PROCESS - > Filtra selecionando somente os restaurantes que fazem pedido online e entrega
#             Fazer uma média para saber qual tipo é mais presente nos restaurantes tem pedidos online e entregas
# INPUT   - > Filter +  'Cuisines', 'Has Online delivery', 'Is delivering now' ,'Country_id', 'City'
Filter = (df["Has Online delivery"] == 1) & (df["Is delivering now"] == 1)
cols =['Restaurant ID','Cuisines', 'Has Online delivery', 'Is delivering now' ,'Country_id', 'City']
cols1 = ['Cuisines','Has Online delivery', 'Is delivering now' ,'Country_id', 'City']
df.loc[Filter, cols ].groupby(cols1).count().reset_index().sort_values('Restaurant ID', ascending=False)
# Out:
#                  Cuisines  Has Online delivery  Is delivering now Country_id  \
# 601          North Indian                    1                  1      India
# 606          North Indian                    1                  1      India
# 869        Pizza, Italian                    1                  1      India
# 610          North Indian                    1                  1      India
# 125     Burger, Fast Food                    1                  1      India
# ..                    ...                  ...                ...        ...
# 377  Fast Food, Beverages                    1                  1      India
# 378  Fast Food, Beverages                    1                  1      India
# 379    Fast Food, Biryani                    1                  1      India
# 380     Fast Food, Burger                    1                  1      India
# 985        Tibetan, Momos                    1                  1      India
#
#              City  Restaurant ID
# ...

# %% [markdown]
# Outra forma de filtrar um dataframe pandas é usar o método isin, que permite verificar se os valores de uma coluna estão em uma lista. Por exemplo:

# %%
#import pandas as pd
# Criando um dataframe de exemplo
#df = pd.DataFrame(data = {
#    "Name": ["Pizza Hut", "Burger King", "Subway", "KFC"],
#    "Has Online delivery": [1, 0, 1, 0],
#    "Is delivering now": [1, 0, 0, 0]
#})
# Filtrando o dataframe usando isin
#df_filtrado = df[df["Name"].isin(["Pizza Hut"])]
# Mostrando o resultado
#print(df_filtrado)
